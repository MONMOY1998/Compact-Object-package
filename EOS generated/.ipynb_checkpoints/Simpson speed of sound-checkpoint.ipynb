# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
mu_1 = 939  # MeV
P_1 = 2.0877  # MeV/fm³
n_0 = 0.16  # fm⁻³
n_1 = 1.1 * n_0  # fm⁻³
epsilon_1 = 165.47  # MeV/fm³
#cs2_1 = 0.22080181
cs2_1 = 0.220979082
#cs2_1 = 0.1385

# %%
def generate_points(N, mu_1=939, mu_N1=2600):
    """
    Generate random mu_points and cs2_points for piecewise linear c_s^2(mu).
    
    Parameters:
    N (int): Number of segments (e.g., 3, 4, 5, 7).
    mu_1 (float): Starting mu value in MeV.
    mu_N1 (float): Ending mu value in MeV.
    
    Returns:
    mu_points (list): List of mu values in increasing order.
    cs2_points (list): List of c_s^2 values corresponding to mu_points.
    """
   # c_s_max2 = np.random.uniform(0, 1)
    c_s_max2 = np.random.uniform(0.82, 1)
    print(c_s_max2)
    if N > 1:
        intermediate_mus = np.random.uniform(mu_1, mu_N1, N-1)
        #intermediate_mus.sort()
        # Sample more points in the crucial density range (2-4× nuclear)
        
        #intermediate_mus.sort()
    else:
        intermediate_mus = []
    mu_points = [mu_1] + list(intermediate_mus) + [mu_N1]

    intermediate_cs2 = np.random.uniform(cs2_1,c_s_max2,N)
    
    cs2_points = [cs2_1] + list(intermediate_cs2)
    #cs2_points.sort()
    
    return mu_points, cs2_points

# %%
# Generate piecewise linear c_s²(μ) parameters
N = 7  # Number of segments, can be 3, 4, 5, or 7
mu_points, cs2_points = generate_points(N, mu_1=939, mu_N1=2600)
# Out:
# 0.8703078534731719

# %%
print(c_s_max2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(c_s_max2)
#
# NameError: name 'c_s_max2' is not defined

# %%
print(cs2_points)
print(mu_points)
# Out:
# [0.220979082, 0.7313848102296778, 0.38112218303323864, 0.47554649292103013, 0.6764816736251755, 0.6160882337338536, 0.3079638940945774, 0.28105003826210434]
# [939, 2394.1611560628494, 1337.1913615202714, 2405.643443411669, 1010.8735887152247, 952.5360943773806, 1363.1328244349384, 2600]

# %%
#Define c_s²(μ) with linear interpolation
def c_s2(mu):
    if mu <= mu_points[0]:
        return cs2_points[0]
    elif mu >= mu_points[-1]:
        return cs2_points[-1]
    for i in range(len(mu_points) - 1):
        if mu_points[i] <= mu <= mu_points[i + 1]:
            return (cs2_points[i] * (mu_points[i + 1] - mu) + cs2_points[i + 1] * (mu - mu_points[i])) / (mu_points[i + 1] - mu_points[i])

# %%
# from scipy.interpolate import interp1d
# c_s2 = interp1d(mu_points, cs2_points, kind='linear', fill_value='extrapolate')

# %%
# Simpson's 1/3 rule implementation
def simpson_integrate(f, a, b, n=200):
    """
    Integrate function f from a to b using Simpson's 1/3 rule.
    
    Parameters:
    f: Function to integrate
    a, b: Integration limits
    n: Number of intervals (must be even)
    
    Returns:
    Integral value
    """
    if n % 2 != 0:
        n += 1  # Ensure n is even
    h = (b - a) / n
    x = np.linspace(a, b, n + 1)
    y = np.array([f(xi) for xi in x])
    return (h / 3) * (y[0] + 4 * np.sum(y[1:-1:2]) + 2 * np.sum(y[2:-2:2]) + y[-1])

# %%
# Integrand for equation (2)
def integrand_eq2(mu_prime):
    cs2 = c_s2(mu_prime)
    return 1 / (mu_prime * cs2) if cs2 != 0 else 0

# n(μ) from equation (2)
def n_mu(mu):
    if mu == mu_1:
        return n_1
    integral = simpson_integrate(integrand_eq2, mu_1, mu)
    return n_1 * np.exp(integral)

# %%
# Integrand for equation (3)
def integrand_eq3(mu_prime):
    return n_mu(mu_prime)

# P(μ) from equation (3)
def P_mu(mu):
    if mu == mu_1:
        return P_1
    integral = simpson_integrate(integrand_eq3, mu_1, mu)
    return P_1 + integral

# %%
# Integrand for equation (4)
def integrand_eq4(mu_prime):
    cs2 = c_s2(mu_prime)
    return n_mu(mu_prime) / cs2 if cs2 != 0 else 0

# ε(μ) from equation (4)
def epsilon_mu(mu):
    if mu == mu_1:
        return epsilon_1
    integral = simpson_integrate(integrand_eq4, mu_1, mu)
    return epsilon_1 + integral

# %%
mu_grid = np.linspace(mu_1, 2600, 200)  # Higher resolution

# %%
# Compute grids
n_grid = np.array([n_mu(mu) for mu in mu_grid])
P_grid = np.array([P_mu(mu) for mu in mu_grid])
cs2_grid = np.array([c_s2(mu) for mu in mu_grid])
epsilon_grid = np.array([epsilon_mu(mu) for mu in mu_grid])

# %%
# Convert n to n/n_0
n_over_n0 = n_grid / n_0
print(n_over_n0)
# Out:
# [ 1.1         1.14464577  1.19007811  1.23628308  1.28324659  1.33095441
#   1.37939224  1.42854567  1.47840023  1.52894144  1.58015477  1.6320257
#   1.68453973  1.73768238  1.79143922  1.84579588  1.90073805  1.95625152
#   2.01232214  2.0689359   2.12607888  2.18373727  2.24189742  2.30054578
#   2.35966897  2.41925372  2.47928695  2.53975572  2.60064723  2.66194888
#   2.72364821  2.78573294  2.84819098  2.91101037  2.97417938  3.03768641
#   3.10152008  3.16566915  3.2301226   3.29486955  3.35989934  3.42520147
#   3.49076562  3.55658165  3.6226396   3.6889297   3.75544235  3.82216811
#   3.88909775  3.95622218  4.0235325   4.09101998  4.15867605  4.22649232
#   4.29446057  4.36257272  4.43082087  4.49919728  4.56769437  4.6363047
#   4.70502101  4.77383617  4.84274322  4.91173532  4.98080581  5.04994815
#   5.11915594  5.18842295  5.25774304  5.32711024  5.39651871  5.46596273
#   5.53543672  5.6049352   5.67445286  5.74398446  5.81352492  5.88306927
#   5.95261264  6.02215029  6.09167759  6.16119001  6.23068313  6.30015265
#   6.36959435  6.43900415  6.50837802  6.57771207  6.64700248  6.71624555
#   6.78543765  6.85457524  6.92365488  6.99267323  7.06162701  7.13051303
#   7.19932819  7.26806947  7.33673392  7.40531869  7.47382097  7.54223805
#   7.6105673   7.67880613  7.74695204  7.81500261  7.88295546  7.95080829
#   8.01855888  8.08620503  8.15374464  8.22117567  8.2884961   8.35570402
#   8.42279754  8.48977484  8.55663414  8.62337374  8.68999197  8.75648722
#   8.82285791  8.88910254  8.95521964  9.02120779  9.08706561  9.15279177
#   9.21838499  9.28384401  9.34916764  9.41435472  9.47940412  9.54431475
#   9.60908557  9.67371558  9.73820381  9.8025493   9.86675118  9.93080856
#   9.99472062 10.05848654 10.12210558 10.18557697 10.24890003 10.31207406
#  10.37509842 10.43797249 10.50069568 10.56326742 10.62568716 10.68795441
#  10.75006866 10.81202945 10.87383635 10.93548894 10.99698683 11.05832964
#  0.52252831 0.52545598 0.52838364 0.5313113  0.53423896 0.53716663
#  0.54009429 0.54302195 0.54594961 0.54887728 0.55180494 0.5547326
#  0.55766026 0.56058793 0.56351559 0.56644325 0.56937091 0.57229858
#  0.57522624 0.5781539  0.58108156 0.58400923 0.58693689 0.58986455
#  0.59279221 0.59571988 0.59864754 0.6015752  0.60450286 0.60743053
#  0.61035819 0.61328585 0.61621351 0.61914118 0.62206884 0.6249965
#  0.62792416 0.63085183 0.63377949 0.63670715 0.63963481 0.64256247
#  0.64549014 0.6484178  0.65134546 0.65427312 0.65720079 0.66012845
#  0.66305611 0.66598377 0.66891144 0.6718391  0.67476676 0.67769442
#  0.68062209 0.68354975 0.68647741 0.68940507 0.69233274 0.6952604
#  0.69818806 0.70111572 0.70404339 0.70697105 0.70989871 0.71282637
#  0.71575404 0.7186817  0.72160936 0.72453702 0.72746469 0.73039235
#  0.47501933 0.28522735 0.28504573 0.28486411 0.28468249 0.28450086
#  0.28431924 0.28413762 0.283956   0.28377437 0.28359275 0.28341113
#  0.28322951 0.28304788 0.28286626 0.28268464 0.28250302 0.2823214
#  0.28213977 0.28195815 0.28177653 0.28159491 0.28141328 0.28123166
#  0.28105004]

# %%
p = P_plot * 1.6022e33
epsilon = epsilon_plot * 1.7827e12

# %%
result_array = np.column_stack((p, epsilon, cs2_plot))

# %%
data_BPS = np.loadtxt("data_k")
pres_BPS = data_BPS[:,0]
rho_BPS = data_BPS[:,1]

# %%
data_polytropic_grok = np.loadtxt("data_polytropic_5")
pres_polytropic = data_polytropic_grok[:,0]
rho_polytropic = data_polytropic_grok[:,1]

# %%
from TOVsolver.unit import g_cm_3, dyn_cm_2, km, Msun, MeV, fm

# %%
pres_total = np.hstack((pres_BPS,pres_polytropic,result_array[:,0]))* dyn_cm_2
eps_total = np.hstack((rho_BPS,rho_polytropic,result_array[:,1]))*g_cm_3
#Last_attempt = np.column_stack((pres_total,eps_total))
#np.savetxt("data_new_1", Last_attempt,  fmt="%.6e")

# %%
print(pres_total)
print(eps_total)
import numpy as np

# Load data
#data_new = np.loadtxt("data_new_1")
#P1 = data_new[:,0] * dyn_cm_2
#rho1 = data_new[:,1] * g_cm_3

P1 = pres_total
rho1 = eps_total

# Check for duplicates in rho1
if len(rho1) != len(np.unique(rho1)):
    print("Duplicate values found in rho1 (density):")
    unique, counts = np.unique(rho1, return_counts=True)
    duplicates = unique[counts > 1]
    print(f"Duplicate density values: {duplicates}")
else:
    print("No duplicates in rho1")

# Check for duplicates in P1
if len(P1) != len(np.unique(P1)):
    print("Duplicate values found in P1 (pressure):")
    unique, counts = np.unique(P1, return_counts=True)
    duplicates = unique[counts > 1]
    print(f"Duplicate pressure values: {duplicates}")
else:
    print("No duplicates in P1")
# Out:
# [3.02141162e-17 1.69068937e-15 7.36119289e-14 ... 9.92657690e+00
#  1.00351613e+01 1.01427237e+01]
# [2.94096142e-11 2.98486062e-10 2.98086978e-09 ... 2.34445820e+01
#  2.37497929e+01 2.41713287e+01]
# No duplicates in rho1
# No duplicates in P1

# %%
# Remove duplicates while keeping the first occurrence
unique_indices = np.unique(rho1, return_index=True)[1]
unique_indices = np.sort(unique_indices)  # Ensure order is preserved
rho1_new = rho1[unique_indices]
P1_new = P1[unique_indices]

print(f"After removing duplicates, rho1 shape: {rho1.shape}, P1 shape: {P1.shape}")
# Out:
# After removing duplicates, rho1 shape: (1283,), P1 shape: (1283,)

# %%
import EOSgenerators.crust_EOS as crust
import EOSgenerators.RMF_EOS as RMF
import EOSgenerators.Polytrope_EOS as Polytrope
import EOSgenerators.Strangeon_EOS as Strangeon
import TOVsolver.main as main
import matplotlib.pyplot as plt
import numpy as np
import math
from TOVsolver.unit import g_cm_3, dyn_cm_2, km, Msun, MeV, fm

# %%
MR_EOS = main.OutputMR("",rho1_new,P1_new).T
MRT_EOS = main.OutputMRT("",rho1_new,P1_new).T

# %%
plt.plot(MR_EOS[1]/km,MR_EOS[0]/Msun)
plt.show()
print(np.max(MR_EOS[0]/Msun))
# Out:
# 2.1542272820941317

# %%
MR_EOS[0]/Msun
# Out:
# array([0.12462229, 0.12938062, 0.13551505, 0.14300131, 0.1517669 ,
#        0.16182573, 0.17317365, 0.21880748, 0.35105697, 0.49931291,
#        0.64979638, 0.7961568 , 0.93538271, 1.06609651, 1.18766262,
#        1.29995342, 1.40311936, 1.49745795, 1.58335609, 1.66127325,
#        1.73164464, 1.79493153, 1.8516021 , 1.9020804 , 1.94676815,
#        1.98608139, 2.02038412, 2.05001327, 2.07530191, 2.0965511 ,
#        2.11406757, 2.12809765, 2.13889755, 2.14670074, 2.15172276,
#        2.15416821, 2.15422728, 2.15207775, 2.1478858 , 2.141807  ,
#        2.13398704, 2.12456265, 2.11366189, 2.10140287, 2.08790153,
#        2.07326253, 2.05759048, 2.04097041, 2.02349363, 2.00524689])

# %%
# Plotting
plt.plot( rho1_new/(g_cm_3*(1.7827e12)), P1_new/(dyn_cm_2*(1.6022e33)))
plt.xlabel('Density (MeV/fm³)')
plt.ylabel('Pressure (MeV/fm³)')
plt.title('Pressure vs Density')
plt.xscale("log")
plt.yscale("log")
plt.xlim([10**2,10**4])
plt.ylim([10**0,10**4])
plt.grid(True)
#plt.legend()
plt.show()

# %%
plt.plot(MRT_EOS[1]/Msun, MRT_EOS[2] ,'g-', lw=2,label ="MS1")
plt.ylim([0,3000])
plt.xlim([0.8,3])
plt.show()

# %%
print(rho1/g_cm_3)
print(len(rho1/g_cm_3))
print(len(P1/dyn_cm_2))
print(len(cs2_plot))

# %%
column_1 = np.ones(1277)  # Placeholder for rho1
column_2 = np.ones(1277)  # Placeholder for P1
column_3 = np.ones(193)  # Placeholder for cs2_plot



# Verify lengths
print("Length of rho1/g_cm_3:", len(column_1))
print("Length of P1/dyn_cm_2:", len(column_2))
print("Length of cs2_plot:", len(column_3))


# Pad cs2_plot to length 1185 with np.nan for the first 1085 elements
cs2_padded = np.full(1277, np.nan)  # Create array of length 1185 filled with NaN
cs2_padded[-193:] = cs2_plot  # Assign last 100 elements from cs2_plot


# Create EOS1 by stacking the arrays
EOS1 = np.column_stack((rho1/g_cm_3, P1/dyn_cm_2, cs2_padded))

# Save EOS1 to a file
np.savetxt("EOS_5.txt", EOS1, header="Density(g/cm^3) Pressure(dyn/cm^2) cs2", fmt="%.6e")

print("EOS3 saved to EOS1_data.txt")
